# %%
# 1
50000*0.03*(1+0.2)

# %%
# 2
k_cost = 50000
rate = 0.03
nt_cost = k_cost * rate
inc = 0.2
nt_price = nt_cost * (1 + inc)
print(nt_price)
# Out:
# 1800.0

# %%
# 3
k_cost = 50000
rate = 0.03
nt_cost = k_cost * rate
inc = 0.2
nt_price = nt_cost * (1 + inc)
s = f'韓國進貨成本是{k_cost}，台幣成本是{nt_cost}，台幣售價是{nt_price:.0f}元'
print(s)
# Out:
# 韓國進貨成本是50000，台幣成本是1500.0，台幣售價是1800元

# %%
# 4
def cal_price(k_cost):
    rate = 0.03
    nt_cost = k_cost * rate
    inc = 0.2
    nt_price = nt_cost * (1 + inc)
    return nt_cost, nt_price

# %%
# 5
k_cost = 45000
nt_cost, nt_price = cal_price(45000)
s = f'韓國進貨成本是{k_cost}，台幣成本是{nt_cost}，台幣售價是{nt_price:.0f}元'
print(s)
# Out:
# 韓國進貨成本是45000，台幣成本是1350.0，台幣售價是1620元

# %%
def cal_price(k_cost):
    rate = 0.03
    nt_cost = k_cost * rate
    inc = 0.2
    nt_price = nt_cost * (1 + inc)
    return nt_cost, nt_price
cal_price(50000)

# %%
# 6
list_k_cost = [30000, 500, 45000, 50000]
for k_cost in list_k_cost:
    nt_cost, nt_price = cal_price(k_cost)
    print(f'韓國進貨成本是{k_cost}，台幣成本是{nt_cost}，台幣售價是{nt_price:.0f}元')
# Out:
# 韓國進貨成本是30000，台幣成本是900.0，台幣售價是1080元
# 韓國進貨成本是500，台幣成本是15.0，台幣售價是18元
# 韓國進貨成本是45000，台幣成本是1350.0，台幣售價是1620元
# 韓國進貨成本是50000，台幣成本是1500.0，台幣售價是1800元

# %%
# 7
list_k_cost = [30000, 500, 45000, 50000]
list_results = []
for k_cost in list_k_cost[:]:
    nt_cost, nt_price = cal_price(k_cost)
    list_results.append([k_cost, nt_cost, nt_price])
list_results
# Out:
# [[30000, 900.0, 1080.0],
#  [500, 15.0, 18.0],
#  [45000, 1350.0, 1620.0],
#  [50000, 1500.0, 1800.0]]

# %%
# 8
def cal_price_dict(k_cost):
    rate = 0.03
    nt_cost = k_cost * rate
    inc = 0.2
    nt_price = nt_cost * (1 + inc)
    data = {
        'k_cost': k_cost,
        'nt_cost': nt_cost,
        'nt_price': nt_price
    }
    return data
cal_price_dict(200)
# Out:
# {'k_cost': 200, 'nt_cost': 6.0, 'nt_price': 7.199999999999999}

# %%
# 9
list_k_cost = [30000, 500, 45000, 50000]
list_results = []
for k_cost in list_k_cost:
    data = cal_price_dict(k_cost)
    list_results.append(data)
list_results
# Out:
# [{'k_cost': 30000, 'nt_cost': 900.0, 'nt_price': 1080.0},
#  {'k_cost': 500, 'nt_cost': 15.0, 'nt_price': 18.0},
#  {'k_cost': 45000, 'nt_cost': 1350.0, 'nt_price': 1620.0},
#  {'k_cost': 50000, 'nt_cost': 1500.0, 'nt_price': 1800.0}]

# %%
# 10
list_k_cost = [30000, 500, 45000, 50000]
list_results = []
for k_cost in list_k_cost:
    if k_cost > 10000:
        data = cal_price_dict(k_cost)
        list_results.append(data)
list_results
# Out:
# [{'k_cost': 30000, 'nt_cost': 900.0, 'nt_price': 1080.0},
#  {'k_cost': 45000, 'nt_cost': 1350.0, 'nt_price': 1620.0},
#  {'k_cost': 50000, 'nt_cost': 1500.0, 'nt_price': 1800.0}]

# %%
# 11
import pandas as pd
df = pd.DataFrame(list_results)
df.columns = ['韓元成本','台幣成本','台幣售價']
df
# Out:
#     韓元成本    台幣成本    台幣售價
# 0  30000   900.0  1080.0
# 1  45000  1350.0  1620.0
# 2  50000  1500.0  1800.0

# %%
import pandas as pd
pd.DataFrame(list_results, columns=['k_cost','nt_cost','np_price'])
# Out:
#    k_cost  nt_cost  np_price
# 0   30000    900.0       NaN
# 1   45000   1350.0       NaN
# 2   50000   1500.0       NaN

# %%
# 12
df.mean()
# Out:
# 韓元成本    41666.666667
# 台幣成本     1250.000000
# 台幣售價     1500.000000
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 0    10660.000000
# 1    15990.000000
# 2    17766.666667
# dtype: float64

# %%
# 13
df.max()
# Out:
# 韓元成本    50000.0
# 台幣成本     1500.0
# 台幣售價     1800.0
# dtype: float64
