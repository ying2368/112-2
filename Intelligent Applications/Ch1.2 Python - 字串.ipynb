# %% [markdown]
# 範例1

# %%
print(ord('a'))
# Out:
# 97

# %% [markdown]
# 範例2

# %%
chr(97)
# Out:
# 'a'

# %% [markdown]
# 範例3

# %%
print('abc')
print("abc")
# Out:
# abc
# abc

# %% [markdown]
# 範例4

# %%
message = 'Hello'
print(message)
# Out:
# Hello

# %% [markdown]
# 範例5

# %%
print(message)
print('message')

# %% [markdown]
# 範例6

# %%
a = 'Hello'
b = "My friend"
a+b
# Out:
# 'HelloMy friend'

# %% [markdown]
# 範例7

# %%
a + " " + b
# Out:
# 'Hello My friend'

# %% [markdown]
# 範例8

# %%
a * 5
# Out:
# 'HelloHelloHelloHelloHello'

# %% [markdown]
# 範例9

# %%
(a + ' ')*5

# %% [markdown]
# 範例10

# %%
a = 'Hello'
b = "My friend"
print(a+b)
# Out:
# HelloMy friend

# %% [markdown]
# 範例11

# %%
a = 'Hello'
b = "My friend"
print(a,b)
# Out:
# Hello My friend

# %% [markdown]
# 範例12

# %%
a = 'Hello'
b = "My friend"
print(a,b,sep='')
# Out:
# HelloMy friend

# %% [markdown]
# 範例13

# %%
a='hello '
b=3
print(a+str(b))
# Out:
# hello 3

# %% [markdown]
# 範例14

# %%
a='hello '
b=3
print(a,b)
# Out:
# hello  3

# %% [markdown]
# 範例15

# %%
print(a)
print(b)
# Out:
# hello
# 3

# %% [markdown]
# 範例16

# %%
print(a, end=' ')
print(b)
# Out:
# hello  3

# %% [markdown]
# 範例17

# %%
print("Hello\nMy friend")
# Out:
# Hello
# My friend

# %% [markdown]
# 範例18

# %%
a='hello '
b=3
f'{a} {b}'
# Out:
# 'hello  3'

# %% [markdown]
# 範例19

# %%
f'{a*3} {b}'
# Out:
# 'HelloHelloHello My friend'

# %% [markdown]
# 範例20

# %%
data = 12500
f'{data:,}'
# Out:
# '12,500'

# %% [markdown]
# 範例21

# %%
f'{data:>10,}'
# Out:
# '    12,500'

# %% [markdown]
# 範例22

# %%
f'{data:*>10,}'
# Out:
# '****12,500'

# %% [markdown]
# 範例23

# %%
f'{data:<10}'
# Out:
# '12500     '

# %% [markdown]
# 範例24

# %%
f'{data:^10}'
# Out:
# '  12500   '

# %% [markdown]
# 範例25

# %%
f_data = 123.8868
f'{f_data:.2f}'
# Out:
# '123.89'

# %% [markdown]
# 範例26

# %%
f_data = 123.8868
f'{f_data:.2%}'
# Out:
# '12388.68%'

# %% [markdown]
# 範例27

# %%
print("*****")
print("*   *")
print("*   *")
print("*****")
# Out:
# *****
# *   *
# *   *
# *****

# %% [markdown]
# 範例28

# %%
print("*****\n*   *\n*   *\n*****")
# Out:
# *****
# *   *
# *   *
# *****

# %% [markdown]
# 範例29

# %%
print("""*****
*   *
*   *
*****""")
# Out:
# *****
# *   *
# *   *
# *****

# %% [markdown]
# 範例30

# %%
print("*"*20)
print("*"," "*18,"*",sep='')
print("*"," "*18,"*",sep='')
print("*"," "*18,"*",sep='')
print("*"*20)
# Out:
# ********************
# *                  *
# *                  *
# *                  *
# ********************

# %% [markdown]
# 範例31

# %%
a="*"*20
b="*"+" "*18+"*"
print(a)
print(b)
print(b)
print(b)
print(a)
# Out:
# ********************
# *                  *
# *                  *
# *                  *
# ********************

# %% [markdown]
# 範例32

# %%
row=50
print("*"*row)
print("*"," "*(row-2),"*",sep='')
print("*"," "*(row-2),"*",sep='')
print("*"," "*(row-2),"*",sep='')
print("*"*row)
# Out:
# **************************************************
# *                                                *
# *                                                *
# *                                                *
# **************************************************

# %% [markdown]
# 範例33

# %%
row = int(input("要幾橫點的表格？"))
print("*"*row)
print("*"+" "*int(row-2)+"*")
print("*"+" "*int(row-2)+"*")
print("*"+" "*int(row-2)+"*")
print("*"*row)
# Out:
# 要幾橫點的表格？3
# ***
# * *
# * *
# * *
# ***

# %% [markdown]
# 範例34

# %%
name = 'peter hsu'
name.title()
# Out:
# 'Peter Hsu'

# %% [markdown]
# 範例35

# %%
name.upper()
# Out:
# 'PETER HSU'

# %% [markdown]
# 範例36

# %%
name.lower()
# Out:
# 'peter hsu'

# %% [markdown]
# 範例37

# %%
name = '    peter  Hsu   '
name.lstrip()
# Out:
# 'peter  Hsu   '

# %% [markdown]
# 範例38

# %%
name.rstrip()
# Out:
# '    peter  Hsu'

# %% [markdown]
# 範例39

# %%
name.strip()
# Out:
# 'peter  Hsu'

# %% [markdown]
# 範例40

# %%
name.replace(' ','')
# Out:
# 'peterHsu'

# %% [markdown]
# 範例41

# %%
name.replace('Hsu','John')
# Out:
# '    peter  John   '

# %% [markdown]
# 範例42

# %%
string = 'hello'
string[0]
# Out:
# 'h'

# %% [markdown]
# 範例43

# %%
'hello'[0]
# Out:
# 'h'

# %% [markdown]
# 範例44

# %%
'hello'[1]
# Out:
# 'e'

# %% [markdown]
# 範例45

# %%
'hello'[-1]

# %% [markdown]
# 範例46

# %%
string[0:2]
# Out:
# 'he'

# %% [markdown]
# 範例47

# %%
string[:2]

# %% [markdown]
# 範例48

# %%
string[2:5]

# %% [markdown]
# 範例49

# %%
string[2:]

# %% [markdown]
# 範例50

# %%
string[::2]

# %% [markdown]
# 範例51

# %%
string[1::2]

# %% [markdown]
# 範例52

# %%
string[::-1]

# %% [markdown]
# 範例53

# %%
string = 'Hello world!'
s1 = string[:5]
s2 = string[6:]
print(s1)
print(s2)
# Out:
# Hello
# world!

# %% [markdown]
# 範例54

# %%
res = string.split(' ')
res
# Out:
# ['Hello', 'world!']

# %% [markdown]
# 範例55

# %%
res[0]
# Out:
# 'Hello'

# %% [markdown]
# 範例56

# %%
res[1]
# Out:
# 'world!'

# %% [markdown]
# 範例57

# %%
string.split(' ')[0]
# Out:
# 'Hello'

# %% [markdown]
# 範例58

# %%
string = 'hello'
string[0]='H'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-349f9f0582ec> in <cell line: 2>()
#       1 string = 'hello'
# ----> 2 string[0]='H'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# 範例59

# %%
string = 'hello'
string = 'H'+string[1:]
string
# Out:
# 'Hello'
