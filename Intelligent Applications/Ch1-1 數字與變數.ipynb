# %%
# 1
2-1
# Out:
# 1

# %%
# 2
1+1
# Out:
# 2

# %%
# 3
2*1
# Out:
# 2

# %%
# 4
3/2
# Out:
# 1.5

# %%
# 5取商
3//2
# Out:
# 1

# %%
# 6取餘
7%3
# Out:
# 1

# %%
# 7次方
2**3
# Out:
# 8

# %%
# 8先乘除後加減
2+5*5+4
# Out:
# 31

# %%
# 9用括號改變優先順序
(2+5)*5+4

# %%
# 10資料型態
type(2)
# Out:
# int

# %%
# 11
type(2.5)
# Out:
# float

# %%
# 12浮點數變成整數
int(2.5)
# Out:
# 2

# %%
# 13字串數變成整數
int('2')
# Out:
# 2

# %%
# 14字串變成浮點數
float('2.38')

# %%
# 15
# a為變數，其值透過=來指定
a = 10

# %%
# 16
a
# Out:
# 10

# %%
# 17
print(a)
# Out:
# 10

# %%
# 18在Python中比較特別的是一次能指定兩個變數的值，但等號的左邊和右邊的個數要相同
x,y = 10,20
print(x,y)
# Out:
# 10 20

# %%
# 19變數a可用來相加
a + a
# Out:
# 20

# %%
# 20相加後存到b
b = a+a
b
# Out:
# 20

# %%
# 21相加後也能存回a
# 在數學上這個式子是不成立的。但在程式語言中，我們是先計算=的右邊，在放回左方的變數
a=a+a
a
# Out:
# 20

# %%
# 22因為常常需要將變數值修改後存回原變數，因此有縮簡的寫法
# 譬如 a = a+1 能簡化成 a += 1
# a = a*5 -> a*=5
a = 5
a = a+5
print(a)
# Out:
# 10

# %%
# 23簡寫
a = 5
a += 5
print(a)
# Out:
# 10

# %%
# 24整數可以說是最簡單的資料型態
# 透過type指令，能知道這筆資料的資料型態
type(a)
# Out:
# int

# %%
# 25
a=30.1
type(a)
# Out:
# float

# %%
# 26
my_cat = 1
type(my_cat)
# Out:
# int

# %%
# 27
my_cat = 'Simon'
type(my_cat)
# Out:
# str

# %%
# 28請注意，數字和文字不能相加
a='hello '
a+3
# 會有錯誤訊息提示
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-6b8b35f318eb> in <cell line: 3>()
#       1 # 28請注意，數字和文字不能相加
#       2 a='hello '
# ----> 3 a+3
#       4 # 會有錯誤訊息提示
#
# TypeError: can only concatenate str (not "int") to str

# %%
# 29最簡單的人機互動指令，input
data = input('請輸入要計算的數學：')
# 使用者輸入後，將其值存入data
print(data)
# 印出data
print(type(data))
# 查看資料型態
# input得到結果為字串'str'

# %%
# 30eval
data = input('請輸入要計算的數學：')
print(eval(data))
